# %% [markdown]
# # Nota: 7.0

# %%
print("como las variables no son identicamente distribuidas, puede ocurrir que algunas de ellas tengan medias o varianzas muy diferentes del resto. Asi, al sumar o promediar, esas variables con cumulantes extremos pueden afectar el comportamiento total. esto corresponderia a un fallo en el teorema, pues no se tendrian las condiciones necesarias para que la distribucion tienda a una normal, esto ocurre porque el teorema requiere un control sobre los cumulantes, como por ejemplo que la varianza no diverga muy rapido. sin estas condiciones las variables que tengan comportamiento extremos cambia la distribucion del limite")
# Out:
# como las variables no son identicamente distribuidas, puede ocurrir que algunas de ellas tengan medias o varianzas muy diferentes del resto. Asi, al sumar o promediar, esas variables con cumulantes extremos pueden afectar el comportamiento total. esto corresponderia a un fallo en el teorema, pues no se tendrian las condiciones necesarias para que la distribucion tienda a una normal, esto ocurre porque el teorema requiere un control sobre los cumulantes, como por ejemplo que la varianza no diverga muy rapido. sin estas condiciones las variables que tengan comportamiento extremos cambia la distribucion del limite
